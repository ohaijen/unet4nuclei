# %%
# %matplotlib inline
import skimage.io
import skimage.morphology
import matplotlib.pyplot as plt

import os.path
import os

import sys
sys.path.insert(0, '/home/jr0th/github/segmentation/code/')

import helper.metrics
import helper.model_builder

import numpy as np

import tensorflow as tf
import keras
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xb but this version of numpy is 0xa
# Using TensorFlow backend.

# %%
debug = True

# %%
cell_min_size = 10**2
boundary_boost_factor = 100

# %%
dir_images = "/home/jr0th/github/segmentation/data/BBBC022/test/x_big/"

tag = "DL_on_CP"

out_dir_probmap = "/home/jr0th/github/segmentation/experiments/" + tag + "/probmap_DL_on_CP_bb/"
out_dir_label = "/home/jr0th/github/segmentation/experiments/" + tag + "/segm_DL_on_CP_bb/"

weights_path = '/home/jr0th/github/segmentation/checkpoints/' + tag + '/checkpoint_0199.hdf5'

# %% [markdown]
# # GET PREDICTIONS

# %%
# build session running on GPU 1
configuration = tf.ConfigProto()
configuration.gpu_options.allow_growth = True
configuration.gpu_options.visible_device_list = "0"
session = tf.Session(config = configuration)

# apply session
keras.backend.set_session(session)

# %%
batch_size = 10

bit_depth = 8

imagebuffer = skimage.io.imread_collection(dir_images + '*.png')
images = imagebuffer.concatenate()

dim1 = images.shape[1]
dim2 = images.shape[2]

images = images.reshape((-1, dim1, dim2, 1))

# preprocess
images = images / 255

# build model and laod weights
model = helper.model_builder.get_model_3_class(dim1, dim2)
model.load_weights(weights_path)

predictions = model.predict(images, batch_size = 10)

print(predictions.shape)
# Out:
# /home/jr0th/github/segmentation/code/helper/model_builder.py:24: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
#   a = keras.layers.Convolution2D(64, 3, 3, **option_dict_conv)(x)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:27: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   a = keras.layers.BatchNormalization(**option_dict_bn)(a)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:31: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
#   a = keras.layers.Convolution2D(64, 3, 3, **option_dict_conv)(a)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:33: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   a = keras.layers.BatchNormalization(**option_dict_bn)(a)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
#   b = keras.layers.Convolution2D(128, 3, 3, **option_dict_conv)(y)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:41: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   b = keras.layers.BatchNormalization(**option_dict_bn)(b)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:45: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
#   b = keras.layers.Convolution2D(128, 3, 3, **option_dict_conv)(b)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:47: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   b = keras.layers.BatchNormalization(**option_dict_bn)(b)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:53: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
#   c = keras.layers.Convolution2D(256, 3, 3, **option_dict_conv)(y)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:55: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   c = keras.layers.BatchNormalization(**option_dict_bn)(c)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:59: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
#   c = keras.layers.Convolution2D(256, 3, 3, **option_dict_conv)(c)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:61: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   c = keras.layers.BatchNormalization(**option_dict_bn)(c)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:67: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", padding="same")`
#   d = keras.layers.Convolution2D(512, 3, 3, **option_dict_conv)(y)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:69: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   d = keras.layers.BatchNormalization(**option_dict_bn)(d)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:73: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", padding="same")`
#   d = keras.layers.Convolution2D(512, 3, 3, **option_dict_conv)(d)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:75: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   d = keras.layers.BatchNormalization(**option_dict_bn)(d)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:83: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   y = keras.layers.merge([d, c], concat_axis=3, mode="concat")
# /usr/local/lib/python3.6/site-packages/keras/legacy/layers.py:460: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:85: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
#   e = keras.layers.Convolution2D(256, 3, 3, **option_dict_conv)(y)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:87: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   e = keras.layers.BatchNormalization(**option_dict_bn)(e)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:91: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
#   e = keras.layers.Convolution2D(256, 3, 3, **option_dict_conv)(e)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:93: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   e = keras.layers.BatchNormalization(**option_dict_bn)(e)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:99: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   y = keras.layers.merge([e, b], concat_axis=3, mode="concat")
# /home/jr0th/github/segmentation/code/helper/model_builder.py:101: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
#   f = keras.layers.Convolution2D(128, 3, 3, **option_dict_conv)(y)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:103: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   f = keras.layers.BatchNormalization(**option_dict_bn)(f)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:107: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
#   f = keras.layers.Convolution2D(128, 3, 3, **option_dict_conv)(f)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:109: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   f = keras.layers.BatchNormalization(**option_dict_bn)(f)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:115: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   y = keras.layers.merge([f, a], concat_axis=3, mode="concat")
# /home/jr0th/github/segmentation/code/helper/model_builder.py:119: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
#   y = keras.layers.Convolution2D(64, 3, 3, **option_dict_conv)(y)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:121: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   y = keras.layers.BatchNormalization(**option_dict_bn)(y)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:125: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
#   y = keras.layers.Convolution2D(64, 3, 3, **option_dict_conv)(y)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:127: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   y = keras.layers.BatchNormalization(**option_dict_bn)(y)
# /home/jr0th/github/segmentation/code/helper/model_builder.py:138: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (1, 1), activation="relu", padding="same")`
#   y = keras.layers.Convolution2D(3, 1, 1, **option_dict_conv)(y)
# (50, 520, 696, 3)

# %%
# print one prediction for debug purposes
if(debug):
    plt.imshow(predictions[42].squeeze())
    plt.show()

# %%
for i in range(len(images)):

    filename = imagebuffer.files[i]
    filename = os.path.basename(filename)
    print(filename)
    
    probmap = predictions[i].squeeze()
    
    plt.imshow(probmap)
    plt.show()
    
    skimage.io.imsave(out_dir_probmap + filename, probmap)
    
    pred = helper.metrics.probmap_to_pred(probmap, boundary_boost_factor)
    
    plt.imshow(pred)
    plt.show()
    
    plt.hist(pred.flatten())
    plt.show()
    
    label = helper.metrics.pred_to_label(pred, cell_min_size)
    
    plt.imshow(label)
    plt.show()
    
    plt.hist(label.flatten())
    plt.show()

    skimage.io.imsave(out_dir_label + filename, label)
# Out:
# IXMtest_A09_s1_w1CE70AD49-290D-4312-82E6-CDC717F32637.png
# /usr/local/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float32 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# IXMtest_A12_s7_w1EAEEA614-51ED-43B3-A4FF-088730911E4C.png
# /usr/local/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/jr0th/github/segmentation/experiments/DL_on_CP/segm_DL_on_CP_bb/IXMtest_A09_s1_w1CE70AD49-290D-4312-82E6-CDC717F32637.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# IXMtest_A16_s2_w15AF20A10-82AE-48FA-AC50-7AE8AC3AA544.png
# /usr/local/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/jr0th/github/segmentation/experiments/DL_on_CP/segm_DL_on_CP_bb/IXMtest_A12_s7_w1EAEEA614-51ED-43B3-A4FF-088730911E4C.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# IXMtest_A22_s8_w1E2AFE190-831D-4D9C-961E-3AA2ECB3599D.png
# /usr/local/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/jr0th/github/segmentation/experiments/DL_on_CP/segm_DL_on_CP_bb/IXMtest_A16_s2_w15AF20A10-82AE-48FA-AC50-7AE8AC3AA544.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# IXMtest_B02_s9_w124B5080D-EBE1-47D2-B147-C0F342039EDF.png
# /usr/local/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/jr0th/github/segmentation/experiments/DL_on_CP/segm_DL_on_CP_bb/IXMtest_A22_s8_w1E2AFE190-831D-4D9C-961E-3AA2ECB3599D.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# IXMtest_B04_s2_w17C6C7F8D-98F7-422B-92CD-EA61EE813325.png
# /usr/local/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/jr0th/github/segmentation/experiments/DL_on_CP/segm_DL_on_CP_bb/IXMtest_B02_s9_w124B5080D-EBE1-47D2-B147-C0F342039EDF.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# IXMtest_B05_s5_w10296BEF4-0F48-4EC8-BC24-6C604871398B.png
# /usr/local/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/jr0th/github/segmentation/experiments/DL_on_CP/segm_DL_on_CP_bb/IXMtest_B04_s2_w17C6C7F8D-98F7-422B-92CD-EA61EE813325.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# IXMtest_C07_s5_w12C9F2926-A017-4962-8660-72C9C20C86E4.png
# /usr/local/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/jr0th/github/segmentation/experiments/DL_on_CP/segm_DL_on_CP_bb/IXMtest_B05_s5_w10296BEF4-0F48-4EC8-BC24-6C604871398B.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# IXMtest_C14_s8_w1612E3D43-FA7E-4FFB-BE53-F34A3A0CAFCD.png
# /usr/local/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/jr0th/github/segmentation/experiments/DL_on_CP/segm_DL_on_CP_bb/IXMtest_C07_s5_w12C9F2926-A017-4962-8660-72C9C20C86E4.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /usr/local/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/jr0th/github/segmentation/experiments/DL_on_CP/segm_DL_on_CP_bb/IXMtest_C14_s8_w1612E3D43-FA7E-4FFB-BE53-F34A3A0CAFCD.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# IXMtest_C23_s2_w10533E965-3DC3-4556-9C26-EA8DD4F8DE61.png
# /usr/local/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/jr0th/github/segmentation/experiments/DL_on_CP/segm_DL_on_CP_bb/IXMtest_C23_s2_w10533E965-3DC3-4556-9C26-EA8DD4F8DE61.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# IXMtest_D01_s1_w181AE787C-B5EE-4150-A90E-2FE43165C32E.png
# IXMtest_D06_s8_w1BE84C8EF-4CD0-4B56-8267-4E662F57AC25.png
# /usr/local/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/jr0th/github/segmentation/experiments/DL_on_CP/segm_DL_on_CP_bb/IXMtest_D01_s1_w181AE787C-B5EE-4150-A90E-2FE43165C32E.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# IXMtest_D08_s7_w1F476A544-A07C-4E9B-A6CB-BAEF4CD6F64E.png
# /usr/local/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/jr0th/github/segmentation/experiments/DL_on_CP/segm_DL_on_CP_bb/IXMtest